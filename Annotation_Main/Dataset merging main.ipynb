# %%
import csv
import pandas as pd

# %% [markdown]
# # Dataset merge and prep for analysis
#
# Checking and renaming the datasets to merge them into one combined dataset and get it ready for (IAA) analysis.
#
# Change folder (Test1, Test2, Main1, Main2...) to process other datasets as they come.

# %%
df1 = pd.read_excel("Main3/Main3_Tamara.xlsx")
df2 = pd.read_excel("Main3/Main3_Katja.xlsx")

# %%
df1 = df1.drop(columns=['Annotation values', 'Chair'])
df2 = df2.drop(columns='Annotation values')

# %%
df1.rename(columns={'Text':'text', 'Annotation': 'tag_tamara', 'Comments': 'comments_tamara','Flag':'flagged_tamara', 'Chair':'chair'}, inplace=True)
df1.head()
# Out:
#                                            ID  \
# 0   ParlaMint-SI_2013-03-04-SDZ6-Redna-11.u10
# 1  ParlaMint-SI_2017-03-21-SDZ7-Redna-28.u162
# 2  ParlaMint-SI_2010-11-16-SDZ5-Izredna-33.u1
# 3  ParlaMint-SI_2010-01-28-SDZ5-Redna-13.u172
# 4   ParlaMint-SI_2021-09-21-SDZ8-Redna-25.u92
#
#                                                 text  tag_tamara  \
# 0  Spoštovani predsednik Vlade, spoštovana minist...    Negative
# 1  Dragi poslanke in poslanci! Danes ne bomo govo...    Negative
# 2  Spoštovane kolegice poslanke in kolegi poslanc...   P_Neutral
# 3  Hvala lepa za besedo, gospod podpredsednik. Sp...  M_Positive
# 4  Hvala za besedo, gospa podpredsednica. Gospe p...  M_Negative
#
#                                      comments_tamara  flagged_tamara
# 0  Based on the first part, in connection with th...             NaN
# 1  Negative theme, negative sentiment, dissapoint...             NaN
# 2                                         Procedural             NaN
# 3  A little diss to the goverment, but overall po...             NaN
# 4  Very conflicting, but the sentiment is mostly ...             NaN

# %%
df2.rename(columns={'Text':'text', 'Annotation': 'tag_katja', 'Comments': 'comments_katja','Flag':'flagged_katja', 'Chair':'chair'}, inplace=True)
df2.head()
# Out:
#                                            ID  \
# 0   ParlaMint-SI_2013-03-04-SDZ6-Redna-11.u10
# 1  ParlaMint-SI_2017-03-21-SDZ7-Redna-28.u162
# 2  ParlaMint-SI_2010-11-16-SDZ5-Izredna-33.u1
# 3  ParlaMint-SI_2010-01-28-SDZ5-Redna-13.u172
# 4   ParlaMint-SI_2021-09-21-SDZ8-Redna-25.u92
#
#                                                 text   tag_katja  \
# 0  Spoštovani predsednik Vlade, spoštovana minist...    Negative
# 1  Dragi poslanke in poslanci! Danes ne bomo govo...    Negative
# 2  Spoštovane kolegice poslanke in kolegi poslanc...   P_Neutral
# 3  Hvala lepa za besedo, gospod podpredsednik. Sp...  M_Negative
# 4  Hvala za besedo, gospa podpredsednica. Gospe p...  M_Negative
#
#                                       comments_katja  flagged_katja  chair
# 0  While the tone is not especially strong as wit...            NaN  False
# 1  First part explaining why the current state is...            NaN  False
# 2                                                NaN            NaN   True
# 3  The very first two sentences seem supportive a...            1.0  False
# 4  Negative topic, but the speaker and their PS s...            1.0  False

# %%
merged_df = pd.merge(df1, df2, on=['ID', 'text'])
merged_df.head()
# Out:
#                                            ID  \
# 0   ParlaMint-SI_2013-03-04-SDZ6-Redna-11.u10
# 1  ParlaMint-SI_2017-03-21-SDZ7-Redna-28.u162
# 2  ParlaMint-SI_2010-11-16-SDZ5-Izredna-33.u1
# 3  ParlaMint-SI_2010-01-28-SDZ5-Redna-13.u172
# 4   ParlaMint-SI_2021-09-21-SDZ8-Redna-25.u92
#
#                                                 text  tag_tamara  \
# 0  Spoštovani predsednik Vlade, spoštovana minist...    Negative
# 1  Dragi poslanke in poslanci! Danes ne bomo govo...    Negative
# 2  Spoštovane kolegice poslanke in kolegi poslanc...   P_Neutral
# 3  Hvala lepa za besedo, gospod podpredsednik. Sp...  M_Positive
# 4  Hvala za besedo, gospa podpredsednica. Gospe p...  M_Negative
#
#                                      comments_tamara  flagged_tamara  \
# 0  Based on the first part, in connection with th...             NaN
# 1  Negative theme, negative sentiment, dissapoint...             NaN
# 2                                         Procedural             NaN
# 3  A little diss to the goverment, but overall po...             NaN
# 4  Very conflicting, but the sentiment is mostly ...             NaN
#
#     tag_katja                                     comments_katja  \
# 0    Negative  While the tone is not especially strong as wit...
# 1    Negative  First part explaining why the current state is...
# 2   P_Neutral                                                NaN
# 3  M_Negative  The very first two sentences seem supportive a...
# 4  M_Negative  Negative topic, but the speaker and their PS s...
#
#    flagged_katja  chair
# 0            NaN  False
# 1            NaN  False
# 2            NaN   True
# 3            1.0  False
# 4            1.0  False

# %%
order = ['ID', 'text', 'tag_tamara', 'tag_katja', 'comments_tamara', 'comments_katja', 'flagged_tamara', 'flagged_katja', 'chair']

# %%
merged_df = merged_df[order]
merged_df['final_tag'] = ''
merged_df.head()
# Out:
#                                            ID  \
# 0   ParlaMint-SI_2013-03-04-SDZ6-Redna-11.u10
# 1  ParlaMint-SI_2017-03-21-SDZ7-Redna-28.u162
# 2  ParlaMint-SI_2010-11-16-SDZ5-Izredna-33.u1
# 3  ParlaMint-SI_2010-01-28-SDZ5-Redna-13.u172
# 4   ParlaMint-SI_2021-09-21-SDZ8-Redna-25.u92
#
#                                                 text  tag_tamara   tag_katja  \
# 0  Spoštovani predsednik Vlade, spoštovana minist...    Negative    Negative
# 1  Dragi poslanke in poslanci! Danes ne bomo govo...    Negative    Negative
# 2  Spoštovane kolegice poslanke in kolegi poslanc...   P_Neutral   P_Neutral
# 3  Hvala lepa za besedo, gospod podpredsednik. Sp...  M_Positive  M_Negative
# 4  Hvala za besedo, gospa podpredsednica. Gospe p...  M_Negative  M_Negative
#
#                                      comments_tamara  \
# 0  Based on the first part, in connection with th...
# 1  Negative theme, negative sentiment, dissapoint...
# 2                                         Procedural
# 3  A little diss to the goverment, but overall po...
# 4  Very conflicting, but the sentiment is mostly ...
#
#                                       comments_katja  flagged_tamara  \
# 0  While the tone is not especially strong as wit...             NaN
# 1  First part explaining why the current state is...             NaN
# 2                                                NaN             NaN
# 3  The very first two sentences seem supportive a...             NaN
# 4  Negative topic, but the speaker and their PS s...             NaN
#
#    flagged_katja  chair final_tag
# 0            NaN  False
# 1            NaN  False
# 2            NaN   True
# 3            1.0  False
# 4            1.0  False

# %%
merged_df.to_csv("Main3/Main3_combined.csv", encoding ='utf-8', index=False)
