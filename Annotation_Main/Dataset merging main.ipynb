# %%
import csv
import pandas as pd

# %% [markdown]
# # Dataset merge and prep for analysis
#
# Checking and renaming the datasets to merge them into one combined dataset and get it ready for (IAA) analysis.
#
# Change folder (Test1, Test2, Main1, Main2...) to process other datasets as they come.

# %%
df1 = pd.read_excel("Main1/Main1_Tamara.xlsx")
df2 = pd.read_excel("Main1/Main1_Katja.xlsx")

# %%
df1 = df1.drop(columns=['Annotation values', 'Chair'])
df2 = df2.drop(columns='Annotation values')

# %%
df1.rename(columns={'Text':'text', 'Annotation': 'tag_tamara', 'Comments': 'comments_tamara','Flag':'flagged_tamara', 'Chair':'chair'}, inplace=True)
df1.head()
# Out:
#                                             ID  \
# 0  ParlaMint-SI_2010-09-07-SDZ5-Izredna-28.u90
# 1   ParlaMint-SI_2011-06-16-SDZ5-Redna-29.u107
# 2   ParlaMint-SI_2011-06-21-SDZ5-Redna-29.u178
# 3   ParlaMint-SI_2020-09-21-SDZ8-Redna-20.u276
# 4   ParlaMint-SI_2009-11-18-SDZ5-Redna-11.u120
#
#                                                 text tag_tamara  \
# 0  Ni replike na repliko. Gospa ministrica, potem...  N_Neutral
# 1  Hvala lepa. Besedo ima Silva Črnugelj. Priprav...  P_Neutral
# 2  Hvala lepa. V bistvu se strinjam z vami, gospo...   Positive
# 3  Hvala, podpredsednik. Hvala tudi za vprašanje,...   Negative
# 4                 Besedo ima gospod Silven Majhenič.  P_Neutral
#
#                                      comments_tamara  flagged_tamara
# 0  Procedural, but he is denying her the ability ...             NaN
# 1                                       Procedural.              NaN
# 2  Speaker is stating positive changes and support.              NaN
# 3  Negative opinion of the topic, the work done, ...             NaN
# 4                                         Procedural             NaN

# %%
df2.rename(columns={'Text':'text', 'Annotation': 'tag_katja', 'Comments': 'comments_katja','Flag':'flagged_katja', 'Chair':'chair'}, inplace=True)

# %%
merged_df = pd.merge(df1, df2, on=['ID', 'text'])
merged_df.head()
# Out:
#                                             ID  \
# 0  ParlaMint-SI_2010-09-07-SDZ5-Izredna-28.u90
# 1   ParlaMint-SI_2011-06-16-SDZ5-Redna-29.u107
# 2   ParlaMint-SI_2011-06-21-SDZ5-Redna-29.u178
# 3   ParlaMint-SI_2020-09-21-SDZ8-Redna-20.u276
# 4   ParlaMint-SI_2009-11-18-SDZ5-Redna-11.u120
#
#                                                 text tag_tamara  \
# 0  Ni replike na repliko. Gospa ministrica, potem...  N_Neutral
# 1  Hvala lepa. Besedo ima Silva Črnugelj. Priprav...  P_Neutral
# 2  Hvala lepa. V bistvu se strinjam z vami, gospo...   Positive
# 3  Hvala, podpredsednik. Hvala tudi za vprašanje,...   Negative
# 4                 Besedo ima gospod Silven Majhenič.  P_Neutral
#
#                                      comments_tamara  flagged_tamara  \
# 0  Procedural, but he is denying her the ability ...             NaN
# 1                                       Procedural.              NaN
# 2  Speaker is stating positive changes and support.              NaN
# 3  Negative opinion of the topic, the work done, ...             NaN
# 4                                         Procedural             NaN
#
#    tag_katja                                     comments_katja  \
# 0  N_Neutral  Procedural, however still has relatively stron...
# 1  P_Neutral                                                NaN
# 2   Positive  Speech seems to be fairly positive, as the spe...
# 3   Negative  Could also be Mixed sentiment due to the last ...
# 4  P_Neutral                                                NaN
#
#    flagged_katja  chair
# 0            NaN   True
# 1            NaN   True
# 2            NaN  False
# 3            1.0  False
# 4            NaN   True

# %%
order = ['ID', 'text', 'tag_tamara', 'tag_katja', 'comments_tamara', 'comments_katja', 'flagged_tamara', 'flagged_katja', 'chair']

# %%
merged_df = merged_df[order]
merged_df['final_tag'] = ''
merged_df.head()
# Out:
#                                             ID  \
# 0  ParlaMint-SI_2010-09-07-SDZ5-Izredna-28.u90
# 1   ParlaMint-SI_2011-06-16-SDZ5-Redna-29.u107
# 2   ParlaMint-SI_2011-06-21-SDZ5-Redna-29.u178
# 3   ParlaMint-SI_2020-09-21-SDZ8-Redna-20.u276
# 4   ParlaMint-SI_2009-11-18-SDZ5-Redna-11.u120
#
#                                                 text tag_tamara  tag_katja  \
# 0  Ni replike na repliko. Gospa ministrica, potem...  N_Neutral  N_Neutral
# 1  Hvala lepa. Besedo ima Silva Črnugelj. Priprav...  P_Neutral  P_Neutral
# 2  Hvala lepa. V bistvu se strinjam z vami, gospo...   Positive   Positive
# 3  Hvala, podpredsednik. Hvala tudi za vprašanje,...   Negative   Negative
# 4                 Besedo ima gospod Silven Majhenič.  P_Neutral  P_Neutral
#
#                                      comments_tamara  \
# 0  Procedural, but he is denying her the ability ...
# 1                                       Procedural.
# 2  Speaker is stating positive changes and support.
# 3  Negative opinion of the topic, the work done, ...
# 4                                         Procedural
#
#                                       comments_katja  flagged_tamara  \
# 0  Procedural, however still has relatively stron...             NaN
# 1                                                NaN             NaN
# 2  Speech seems to be fairly positive, as the spe...             NaN
# 3  Could also be Mixed sentiment due to the last ...             NaN
# 4                                                NaN             NaN
#
#    flagged_katja  chair final_tag
# 0            NaN   True
# 1            NaN   True
# 2            NaN  False
# 3            1.0  False
# 4            NaN   True

# %%
merged_df.to_csv("Main1/Main1_combined.csv", encoding ='utf-8', index=False)
