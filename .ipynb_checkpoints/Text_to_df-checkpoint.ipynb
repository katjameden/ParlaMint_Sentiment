# %%
import pandas as pd
import os

# %%
root_directory = "ParlaMint-SI/ParlaMint-SI.txt"

# %%
ids = []
texts = []

# %%
for root, _, files in os.walk(root_directory):
    for filename in files: 
        if filename.endswith(".txt") and filename != "00README.txt":
            filepath = os.path.join(root, filename)
            with open(filepath, 'r', encoding = 'utf-8') as file:
                for line in file:
                    if '\t' in line:  # Ensure the line contains a tab character
                        parts = line.strip().split('\t')
                        if len(parts) == 2:  # Ensure there are exactly two parts after splitting
                            ids.append(parts[0])
                            texts.append(parts[1])

# %%
data = pd.DataFrame({
    'ID': ids,
    'Text': texts
})

# %%
data
# Out:
#                                                        ID
# 0       ParlaMint-SI_2013-03-27-SDZ6-Redna-12.u1\tSpoš...  \
# 1         ParlaMint-SI_2013-03-27-SDZ6-Redna-12.u2\tHvala
# 2         ParlaMint-SI_2013-03-27-SDZ6-Redna-12.u3\tHvala
# 3       ParlaMint-SI_2013-03-27-SDZ6-Redna-12.u4\tSpoš...
# 4         ParlaMint-SI_2013-03-27-SDZ6-Redna-12.u5\tHvala
# ...                                                   ...
# 310329  ParlaMint-SI_2004-12-03-SDZ4-Izredna-04.u251\t...
# 310330  ParlaMint-SI_2004-12-03-SDZ4-Izredna-04.u252\t...
# 310331  ParlaMint-SI_2004-12-03-SDZ4-Izredna-04.u253\t...
# 310332  ParlaMint-SI_2004-12-03-SDZ4-Izredna-04.u254\t...
# 310333  ParlaMint-SI_2004-12-03-SDZ4-Izredna-04.u255\tKer
#
#                                                      Text
# 0       kolegice poslanke in kolegi poslanci, gospe in...
# 1       lepa za besedo. Spoštovana predsednica Vlade, ...
# 2       tudi vam. Dajem besedo predsednici Vlade. Mag....
# 3       poslanke in poslanci, lep pozdrav prvič s tega...
# 4       za odgovor. Gospod Prevc bo predstavil zahtevo...
# ...                                                   ...
# 310329  bo zaprisegel dr. Jure Zupan, minister za viso...
# 310330  da bom spoštoval ustavni red, da bom ravnal po...
# 310331  in zadnji bo zaprisegel dr. Milan Zver, minist...
# 310332  da bom spoštoval ustavni red, da bom ravnal po...
# 310333  so bili poslanci dr. Andrej Bajuk, specialist ...
#
# [310334 rows x 2 columns]

# %%
output_file = 'list.tsv'
data.to_csv(output_file, sep='\t', index=False)

print(f"Combined data saved to {output_file}")
# Out:
# Combined data saved to list.tsv
