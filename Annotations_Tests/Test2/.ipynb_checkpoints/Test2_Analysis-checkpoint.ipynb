# %%
import pandas as pd
import csv

# %%
df = pd.read_csv("Test2_combined.csv", delimiter = ',', encoding='utf-8')

# %%
df
# Out:
#                                               ID
# 0     ParlaMint-SI_2013-06-21-SDZ6-Izredna-39.u1  \
# 1    ParlaMint-SI_2013-04-26-SDZ6-Izredna-33.u41
# 2      ParlaMint-SI_2013-11-20-SDZ6-Redna-19.u47
# 3     ParlaMint-SI_2013-11-20-SDZ6-Redna-19.u147
# 4     ParlaMint-SI_2013-11-20-SDZ6-Redna-19.u247
# 5      ParlaMint-SI_2013-01-31-SDZ6-Redna-10.u49
# 6     ParlaMint-SI_2013-01-31-SDZ6-Redna-10.u149
# 7     ParlaMint-SI_2013-01-31-SDZ6-Redna-10.u249
# 8      ParlaMint-SI_2013-07-10-SDZ6-Redna-16.u96
# 9      ParlaMint-SI_2013-03-05-SDZ6-Redna-11.u43
# 10    ParlaMint-SI_2013-03-05-SDZ6-Redna-11.u143
# 11     ParlaMint-SI_2013-11-27-SDZ6-Redna-19.u83
# 12    ParlaMint-SI_2013-11-27-SDZ6-Redna-19.u183
# 13    ParlaMint-SI_2013-11-27-SDZ6-Redna-19.u283
# 14     ParlaMint-SI_2013-06-18-SDZ6-Redna-15.u65
# 15    ParlaMint-SI_2013-06-18-SDZ6-Redna-15.u165
# 16   ParlaMint-SI_2013-11-29-SDZ6-Izredna-48.u34
# 17  ParlaMint-SI_2013-11-29-SDZ6-Izredna-48.u134
# 18     ParlaMint-SI_2013-06-20-SDZ6-Redna-15.u60
# 19    ParlaMint-SI_2013-06-20-SDZ6-Redna-15.u160
# 20    ParlaMint-SI_2013-06-20-SDZ6-Redna-15.u260
# 21     ParlaMint-SI_2013-04-24-SDZ6-Redna-13.u53
# 22    ParlaMint-SI_2013-04-24-SDZ6-Redna-13.u153
# 23    ParlaMint-SI_2013-04-24-SDZ6-Redna-13.u253
# 24   ParlaMint-SI_2013-12-12-SDZ6-Izredna-50.u47
# 25   ParlaMint-SI_2013-12-12-SDZ6-Izredna-51.u38
# 26   ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u95
# 27  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u195
# 28  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u295
# 29  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u395
# 30  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u495
# 31  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u595
# 32  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u695
# 33  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u795
# 34  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u895
# 35  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u995
# 36   ParlaMint-SI_2013-09-20-SDZ6-Izredna-43.u78
# 37  ParlaMint-SI_2013-09-20-SDZ6-Izredna-43.u178
# 38     ParlaMint-SI_2013-03-06-SDZ6-Redna-11.u57
# 39     ParlaMint-SI_2013-03-27-SDZ6-Redna-12.u72
# 40     ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u18
# 41    ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u118
# 42    ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u218
# 43    ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u318
# 44     ParlaMint-SI_2013-04-23-SDZ6-Redna-13.u86
# 45     ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u37
# 46    ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u137
# 47    ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u237
# 48    ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u337
# 49     ParlaMint-SI_2013-07-15-SDZ6-Redna-16.u97
#
#                                                  text  tag_tamara   tag_katja
# 0   Spoštovani kolegice poslanke in kolegi poslanc...   P_Neutral   P_Neutral  \
# 1   Hvala lepa, spoštovani gospod predsednik. Gosp...   N_Neutral  M_Positive
# 2   Hvala lepa. Gospod Černač, izvolite v imenu pr...   P_Neutral   P_Neutral
# 3   Hvala lepa. Gospod Černač v imenu predlagatelj...   P_Neutral   P_Neutral
# 4   Bom zelo kratek. Tam za mizo smo imeli vodje p...    Negative    Negative
# 5   Hvala lepa. Besedo ima gospa Alenka Jeraj, pri...   P_Neutral   P_Neutral
# 6                                 Minister, izvolite.   P_Neutral   P_Neutral
# 7   Hvala lepa. S tem zaključujem razpravo. Na pod...   P_Neutral   P_Neutral
# 8   Da, seveda, da ne bi izzvenelo, da so bile moj...    Negative    Negative
# 9          Hvala lepa. Besedo ima gospod Mirko Brulc.   P_Neutral   P_Neutral
# 10  Hvala za besedo. Že prejšnji amandma sem podpr...    Positive    Positive
# 11  Hvala lepa, gospod Grill. V imenu Poslanske sk...   P_Neutral   P_Neutral
# 12  Hvala lepa. Poslanska skupina Pozitivna Sloven...   P_Neutral   P_Neutral
# 13  Hvala lepa tudi vam. Gospod Franc Bogovič, izv...   P_Neutral   P_Neutral
# 14  Hvala. Sicer pa bomo o amandmajih v skladu s č...   P_Neutral   P_Neutral
# 15  Hvala lepa. Kot sem napovedal že v stališču po...    Negative    Negative
# 16  Hvala lepa, gospod predsednik, za besedo. Spoš...   N_Neutral    Negative
# 17         To je prvi del. Drugi del je pa to [[...]]   P_Neutral   P_Neutral
# 18  Povejte, prosim, kateri so zaslužni za to, da ...    Negative    Negative
# 19  Hvala, gospa predsedujoča. Kolegice in kolegi!...    Negative  M_Negative
# 20  Hvala tudi vam. Gospod Branko Ficko bo obrazlo...   P_Neutral   P_Neutral
# 21  Hvala. Mag. Marko Pogačnik bo predstavil stali...   P_Neutral   P_Neutral
# 22  Hvala lepa, gospa podpredsednica. Spoštovani g...   P_Neutral   P_Neutral
# 23  Hvala lepa. Prehajamo na glasovanje. Prekinjam...   P_Neutral   P_Neutral
# 24  Hvala lepa. Kot predlagatelj ste se javili, go...   P_Neutral   N_Neutral
# 25  Hvala lepa, gospod predsednik. Moj postopkovni...   N_Neutral    Negative
# 26           Hvala. Besedo ima gospod Jožef Jerovšek.   P_Neutral   P_Neutral
# 27  Hvala. Besedo ima gospod Matevž Frangež. Izvol...   P_Neutral   P_Neutral
# 28  Hvala. Amandma Slovenske demokratske stranke b...  M_Negative  M_Negative
# 29  Hvala lepa. Niti nisem želela odreagirati na t...    Negative    Negative
# 30  Res so bili koalicijski poslanci doslej bolj r...    Negative  M_Positive
# 31  Že prej sem vas prosil, predsedujoča, le da je...    Negative    Negative
# 32  Gospa podpredsednica, lepo vas prosim, da pozo...    Negative    Negative
# 33  Želi še kdo obrazložiti glas? Ugotavljam, da n...   P_Neutral   P_Neutral
# 34  Hvala. Besedo ima gospod Franc Pukšič v imenu ...   P_Neutral   P_Neutral
# 35  Hvala lepa. 45. člen zakona o izvrševanju pror...    Negative    Negative
# 36  Hvala lepa. To vsekakor zahteva nek odziv na t...    Negative    Negative
# 37  Še enkrat, amandma k prvi točki govori o tem, ...    Positive   P_Neutral
# 38  Hvala lepa. Besedo ima mag. Ivan Vogrin. Vidim...   P_Neutral   P_Neutral
# 39  Spoštovani gospod predsednik, hvala za besedo....    Positive    Positive
# 40  Najlepša hvala, gospa Novak, za to vprašanje. ...  M_Positive  M_Positive
# 41  Hvala lepa. To, kar je sedaj nazadnje rekel mi...    Positive    Negative
# 42  Hvala. V zvezi s problematiko ravnanja z odpad...   P_Neutral   P_Neutral
# 43         Hvala lepa. Dr. Anja Kopač Mrak, izvolite.   P_Neutral   P_Neutral
# 44  Spoštovana predsedujoča, predstavniki Vlade, k...  M_Positive  M_Positive
# 45  Hvala. Postopkovno zahtevo ima gospa Ljudmila ...   P_Neutral   P_Neutral
# 46                         Gospod minister, izvolite.   P_Neutral   P_Neutral
# 47  Najlepša hvala, gospod poslanec Breznik. Z vam...   P_Neutral  M_Positive
# 48  Hvala za dodatno vprašanje. Dejansko je res, g...   P_Neutral  M_Negative
# 49  Sledim gospa Potrata. Tri minute so ravnokar m...   N_Neutral   N_Neutral
#
#                                       comments_tamara
# 0            Purely ceremnial, opening of a session.   \
# 1                                Lots of facts, TLDR…
# 2                                          Procedural
# 3                                          Procedural
# 4   Could be N_Neutral also, but I thing this has ...
# 5                                          Procedural
# 6                                          Procedural
# 7                                          Procedural
# 8                       Negative, mocking sentiment.
# 9                                        Ceremonial.
# 10                            Support for something,
# 11                                         Procedural
# 12                                         Procedural
# 13                                         Procedural
# 14                   Procedural, the speakers words.
# 15  Although the speaker expresses a rather neutra...
# 16  States objective facts that shows some negativ...
# 17                                         Procedural
# 18             I also think this could be sarcastic.
# 19            Negative opinion and also ''očitajoče''
# 20                                         Procedural
# 21                                         Procedural
# 22  Although it expresses a support for the amendm...
# 23                                         Procedural
# 24                                         Procedural
# 25  Rather neutral,questions, but a bit of a negat...
# 26                                         Procedural
# 27                                         Procedural
# 28  First part support of, but second part express...
# 29               Clearly expressed negative opinion.
# 30  I think this is ''očitajoče'' towards the pres...
# 31                                Expressed opinion.
# 32                                 mocking, demanding
# 33                                         Procedural
# 34                                         Procedural
# 35  Although in the name of a group, it clearly ex...
# 36                  Expressive, negative words used.
# 37                        Support, nothing negative.
# 38                                       Procedural.
# 39                           Clear widespread support
# 40  Some positive - priority for the youth, but al...
# 41  Despite the negative word ''zlorabiti'' this i...
# 42                                        Just facts.
# 43                                       Procedural.
# 44  At first very negative topic and fact, but at ...
# 45                                         Procedural
# 46                                         Procedural
# 47  Although there is some agreement in the first ...
# 48  Pure facts, although if we look at it from the...
# 49              Ceremonialno, z negativnim prizvokom.
#
#                                        comments_katja flagged_tamara
# 0                            Procedural, no sentiment            NaN  \
# 1   Speaker talks about a very negative topic of c...              T
# 2                                                 NaN            NaN
# 3                                                 NaN            NaN
# 4                                                 NaN            NaN
# 5                                                 NaN            NaN
# 6                                                 NaN            NaN
# 7   Procedural, slight negative sentiment due to t...            NaN
# 8                                                 NaN            NaN
# 9                                                 NaN            NaN
# 10                                                NaN            NaN
# 11                                                NaN            NaN
# 12                                                NaN            NaN
# 13                                                NaN            NaN
# 14                                                NaN            NaN
# 15                                                NaN            NaN
# 16                                                NaN            NaN
# 17                                                NaN            NaN
# 18                                                NaN            NaN
# 19                                                NaN            NaN
# 20                                                NaN            NaN
# 21                                                NaN            NaN
# 22  Lots of factual statements, with regards to th...            NaN
# 23                                                NaN            NaN
# 24                                                NaN            NaN
# 25                                                NaN            NaN
# 26                                                NaN            NaN
# 27                                                NaN            NaN
# 28  First part positive ("I will support, because....            NaN
# 29                                                NaN            NaN
# 30  Very mixed, sentiment changes several times th...            NaN
# 31                                                NaN            NaN
# 32                                                NaN            NaN
# 33                                                NaN            NaN
# 34                                                NaN            NaN
# 35                                                NaN            NaN
# 36                                                NaN            NaN
# 37  Difficult to pinpoint sentiment, as it seems r...            NaN
# 38                                                NaN            NaN
# 39  Again, very neutral, or at least not with very...            NaN
# 40  First part very negative and dealing with accu...            NaN
# 41                                                NaN            NaN
# 42                                                NaN            NaN
# 43                                                NaN            NaN
# 44                                                NaN            NaN
# 45                                                NaN            NaN
# 46                                                NaN            NaN
# 47                                                NaN            NaN
# 48                                                NaN            NaN
# 49                                                NaN            NaN
#
#    flagged_katja chair  final_tag
# 0            NaN  True        NaN
# 1            NaN   NaN        NaN
# 2            NaN  True        NaN
# 3            NaN  True        NaN
# 4            NaN   NaN        NaN
# 5            NaN  True        NaN
# 6            NaN  True        NaN
# 7            NaN  True        NaN
# 8            NaN   NaN        NaN
# 9            NaN  True        NaN
# 10           NaN   NaN        NaN
# 11           NaN  True        NaN
# 12           NaN  True        NaN
# 13           NaN  True        NaN
# 14           NaN  True        NaN
# 15           NaN   NaN        NaN
# 16           NaN   NaN        NaN
# 17           NaN   NaN        NaN
# 18           NaN   NaN        NaN
# 19          True   NaN        NaN
# 20           NaN  True        NaN
# 21           NaN  True        NaN
# 22           NaN   NaN        NaN
# 23           NaN  True        NaN
# 24           NaN  True        NaN
# 25           NaN   NaN        NaN
# 26           NaN  True        NaN
# 27           NaN  True        NaN
# 28           NaN   NaN        NaN
# 29           NaN   NaN        NaN
# 30          True   NaN        NaN
# 31           NaN   NaN        NaN
# 32           NaN   NaN        NaN
# 33           NaN  True        NaN
# 34           NaN  True        NaN
# 35           NaN   NaN        NaN
# 36           NaN   NaN        NaN
# 37          True   NaN        NaN
# 38           NaN  True        NaN
# 39          True   NaN        NaN
# 40          True   NaN        NaN
# 41           NaN   NaN        NaN
# 42           NaN   NaN        NaN
# 43           NaN  True        NaN
# 44           NaN   NaN        NaN
# 45           NaN  True        NaN
# 46           NaN  True        NaN
# 47          True   NaN        NaN
# 48           NaN   NaN        NaN
# 49           NaN  True        NaN

# %% [markdown]
# # 6-level schema analysis (Cohen's Kappa (κ))

# %%
from sklearn.metrics import cohen_kappa_score
annotator1 = df['tag_tamara']
annotator2 = df['tag_katja']
cohen_kappa_score(annotator1, annotator2)
# Out:
# 0.6896337678460583

# %% [markdown]
# # κ for non-procedural and procedural speech

# %%
df_non = df[df['chair'] != True]

# %%
df_procedural = df[df['chair'] == True]

# %%
df_procedural
# Out:
#                                               ID
# 0     ParlaMint-SI_2013-06-21-SDZ6-Izredna-39.u1  \
# 2      ParlaMint-SI_2013-11-20-SDZ6-Redna-19.u47
# 3     ParlaMint-SI_2013-11-20-SDZ6-Redna-19.u147
# 5      ParlaMint-SI_2013-01-31-SDZ6-Redna-10.u49
# 6     ParlaMint-SI_2013-01-31-SDZ6-Redna-10.u149
# 7     ParlaMint-SI_2013-01-31-SDZ6-Redna-10.u249
# 9      ParlaMint-SI_2013-03-05-SDZ6-Redna-11.u43
# 11     ParlaMint-SI_2013-11-27-SDZ6-Redna-19.u83
# 12    ParlaMint-SI_2013-11-27-SDZ6-Redna-19.u183
# 13    ParlaMint-SI_2013-11-27-SDZ6-Redna-19.u283
# 14     ParlaMint-SI_2013-06-18-SDZ6-Redna-15.u65
# 20    ParlaMint-SI_2013-06-20-SDZ6-Redna-15.u260
# 21     ParlaMint-SI_2013-04-24-SDZ6-Redna-13.u53
# 23    ParlaMint-SI_2013-04-24-SDZ6-Redna-13.u253
# 24   ParlaMint-SI_2013-12-12-SDZ6-Izredna-50.u47
# 26   ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u95
# 27  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u195
# 33  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u795
# 34  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u895
# 38     ParlaMint-SI_2013-03-06-SDZ6-Redna-11.u57
# 43    ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u318
# 45     ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u37
# 46    ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u137
# 49     ParlaMint-SI_2013-07-15-SDZ6-Redna-16.u97
#
#                                                  text tag_tamara  tag_katja
# 0   Spoštovani kolegice poslanke in kolegi poslanc...  P_Neutral  P_Neutral  \
# 2   Hvala lepa. Gospod Černač, izvolite v imenu pr...  P_Neutral  P_Neutral
# 3   Hvala lepa. Gospod Černač v imenu predlagatelj...  P_Neutral  P_Neutral
# 5   Hvala lepa. Besedo ima gospa Alenka Jeraj, pri...  P_Neutral  P_Neutral
# 6                                 Minister, izvolite.  P_Neutral  P_Neutral
# 7   Hvala lepa. S tem zaključujem razpravo. Na pod...  P_Neutral  P_Neutral
# 9          Hvala lepa. Besedo ima gospod Mirko Brulc.  P_Neutral  P_Neutral
# 11  Hvala lepa, gospod Grill. V imenu Poslanske sk...  P_Neutral  P_Neutral
# 12  Hvala lepa. Poslanska skupina Pozitivna Sloven...  P_Neutral  P_Neutral
# 13  Hvala lepa tudi vam. Gospod Franc Bogovič, izv...  P_Neutral  P_Neutral
# 14  Hvala. Sicer pa bomo o amandmajih v skladu s č...  P_Neutral  P_Neutral
# 20  Hvala tudi vam. Gospod Branko Ficko bo obrazlo...  P_Neutral  P_Neutral
# 21  Hvala. Mag. Marko Pogačnik bo predstavil stali...  P_Neutral  P_Neutral
# 23  Hvala lepa. Prehajamo na glasovanje. Prekinjam...  P_Neutral  P_Neutral
# 24  Hvala lepa. Kot predlagatelj ste se javili, go...  P_Neutral  N_Neutral
# 26           Hvala. Besedo ima gospod Jožef Jerovšek.  P_Neutral  P_Neutral
# 27  Hvala. Besedo ima gospod Matevž Frangež. Izvol...  P_Neutral  P_Neutral
# 33  Želi še kdo obrazložiti glas? Ugotavljam, da n...  P_Neutral  P_Neutral
# 34  Hvala. Besedo ima gospod Franc Pukšič v imenu ...  P_Neutral  P_Neutral
# 38  Hvala lepa. Besedo ima mag. Ivan Vogrin. Vidim...  P_Neutral  P_Neutral
# 43         Hvala lepa. Dr. Anja Kopač Mrak, izvolite.  P_Neutral  P_Neutral
# 45  Hvala. Postopkovno zahtevo ima gospa Ljudmila ...  P_Neutral  P_Neutral
# 46                         Gospod minister, izvolite.  P_Neutral  P_Neutral
# 49  Sledim gospa Potrata. Tri minute so ravnokar m...  N_Neutral  N_Neutral
#
#                              comments_tamara
# 0   Purely ceremnial, opening of a session.   \
# 2                                 Procedural
# 3                                 Procedural
# 5                                 Procedural
# 6                                 Procedural
# 7                                 Procedural
# 9                               Ceremonial.
# 11                                Procedural
# 12                                Procedural
# 13                                Procedural
# 14          Procedural, the speakers words.
# 20                                Procedural
# 21                                Procedural
# 23                                Procedural
# 24                                Procedural
# 26                                Procedural
# 27                                Procedural
# 33                                Procedural
# 34                                Procedural
# 38                              Procedural.
# 43                              Procedural.
# 45                                Procedural
# 46                                Procedural
# 49     Ceremonialno, z negativnim prizvokom.
#
#                                        comments_katja flagged_tamara
# 0                            Procedural, no sentiment            NaN  \
# 2                                                 NaN            NaN
# 3                                                 NaN            NaN
# 5                                                 NaN            NaN
# 6                                                 NaN            NaN
# 7   Procedural, slight negative sentiment due to t...            NaN
# 9                                                 NaN            NaN
# 11                                                NaN            NaN
# 12                                                NaN            NaN
# 13                                                NaN            NaN
# 14                                                NaN            NaN
# 20                                                NaN            NaN
# 21                                                NaN            NaN
# 23                                                NaN            NaN
# 24                                                NaN            NaN
# 26                                                NaN            NaN
# 27                                                NaN            NaN
# 33                                                NaN            NaN
# 34                                                NaN            NaN
# 38                                                NaN            NaN
# 43                                                NaN            NaN
# 45                                                NaN            NaN
# 46                                                NaN            NaN
# 49                                                NaN            NaN
#
#    flagged_katja chair  final_tag
# 0            NaN  True        NaN
# 2            NaN  True        NaN
# 3            NaN  True        NaN
# 5            NaN  True        NaN
# 6            NaN  True        NaN
# 7            NaN  True        NaN
# 9            NaN  True        NaN
# 11           NaN  True        NaN
# 12           NaN  True        NaN
# 13           NaN  True        NaN
# 14           NaN  True        NaN
# 20           NaN  True        NaN
# 21           NaN  True        NaN
# 23           NaN  True        NaN
# 24           NaN  True        NaN
# 26           NaN  True        NaN
# 27           NaN  True        NaN
# 33           NaN  True        NaN
# 34           NaN  True        NaN
# 38           NaN  True        NaN
# 43           NaN  True        NaN
# 45           NaN  True        NaN
# 46           NaN  True        NaN
# 49           NaN  True        NaN

# %%
annotator1 = df_non['tag_tamara']
annotator2 = df_non['tag_katja']
cohen_kappa_score(annotator1, annotator2)
# Out:
# 0.5347912524850895

# %%
annotator1_procedural = df_procedural['tag_tamara']
annotator2_procedural = df_procedural['tag_katja']
cohen_kappa_score(annotator1_procedural, annotator2_procedural)
# Out:
# 0.6470588235294118

# %% [markdown]
# # 3-level analysis (Cohen's Kappa (κ))

# %%
df.loc[(df['tag_tamara'] == 'Negative') | (df['tag_tamara'] == 'M_Negative'), 'sent_tamara'] = 'Negative'
df.loc[(df['tag_tamara'] == 'Positive') | (df['tag_tamara'] == 'M_Positive'), 'sent_tamara'] = 'Positive'
df.loc[(df['tag_tamara'] == 'P_Neutral') | (df['tag_tamara'] == 'N_Neutral'), 'sent_tamara'] = 'Neutral'

# %%
df.loc[(df['tag_katja'] == 'Negative') | (df['tag_katja'] == 'M_Negative'), 'sent_katja'] = 'Negative'
df.loc[(df['tag_katja'] == 'Positive') | (df['tag_katja'] == 'M_Positive'), 'sent_katja'] = 'Positive'
df.loc[(df['tag_katja'] == 'P_Neutral') | (df['tag_katja'] == 'N_Neutral'), 'sent_katja'] = 'Neutral'

# %%
df
# Out:
#                                               ID
# 0     ParlaMint-SI_2013-06-21-SDZ6-Izredna-39.u1  \
# 1    ParlaMint-SI_2013-04-26-SDZ6-Izredna-33.u41
# 2      ParlaMint-SI_2013-11-20-SDZ6-Redna-19.u47
# 3     ParlaMint-SI_2013-11-20-SDZ6-Redna-19.u147
# 4     ParlaMint-SI_2013-11-20-SDZ6-Redna-19.u247
# 5      ParlaMint-SI_2013-01-31-SDZ6-Redna-10.u49
# 6     ParlaMint-SI_2013-01-31-SDZ6-Redna-10.u149
# 7     ParlaMint-SI_2013-01-31-SDZ6-Redna-10.u249
# 8      ParlaMint-SI_2013-07-10-SDZ6-Redna-16.u96
# 9      ParlaMint-SI_2013-03-05-SDZ6-Redna-11.u43
# 10    ParlaMint-SI_2013-03-05-SDZ6-Redna-11.u143
# 11     ParlaMint-SI_2013-11-27-SDZ6-Redna-19.u83
# 12    ParlaMint-SI_2013-11-27-SDZ6-Redna-19.u183
# 13    ParlaMint-SI_2013-11-27-SDZ6-Redna-19.u283
# 14     ParlaMint-SI_2013-06-18-SDZ6-Redna-15.u65
# 15    ParlaMint-SI_2013-06-18-SDZ6-Redna-15.u165
# 16   ParlaMint-SI_2013-11-29-SDZ6-Izredna-48.u34
# 17  ParlaMint-SI_2013-11-29-SDZ6-Izredna-48.u134
# 18     ParlaMint-SI_2013-06-20-SDZ6-Redna-15.u60
# 19    ParlaMint-SI_2013-06-20-SDZ6-Redna-15.u160
# 20    ParlaMint-SI_2013-06-20-SDZ6-Redna-15.u260
# 21     ParlaMint-SI_2013-04-24-SDZ6-Redna-13.u53
# 22    ParlaMint-SI_2013-04-24-SDZ6-Redna-13.u153
# 23    ParlaMint-SI_2013-04-24-SDZ6-Redna-13.u253
# 24   ParlaMint-SI_2013-12-12-SDZ6-Izredna-50.u47
# 25   ParlaMint-SI_2013-12-12-SDZ6-Izredna-51.u38
# 26   ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u95
# 27  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u195
# 28  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u295
# 29  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u395
# 30  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u495
# 31  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u595
# 32  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u695
# 33  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u795
# 34  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u895
# 35  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u995
# 36   ParlaMint-SI_2013-09-20-SDZ6-Izredna-43.u78
# 37  ParlaMint-SI_2013-09-20-SDZ6-Izredna-43.u178
# 38     ParlaMint-SI_2013-03-06-SDZ6-Redna-11.u57
# 39     ParlaMint-SI_2013-03-27-SDZ6-Redna-12.u72
# 40     ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u18
# 41    ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u118
# 42    ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u218
# 43    ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u318
# 44     ParlaMint-SI_2013-04-23-SDZ6-Redna-13.u86
# 45     ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u37
# 46    ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u137
# 47    ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u237
# 48    ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u337
# 49     ParlaMint-SI_2013-07-15-SDZ6-Redna-16.u97
#
#                                                  text  tag_tamara   tag_katja
# 0   Spoštovani kolegice poslanke in kolegi poslanc...   P_Neutral   P_Neutral  \
# 1   Hvala lepa, spoštovani gospod predsednik. Gosp...   N_Neutral  M_Positive
# 2   Hvala lepa. Gospod Černač, izvolite v imenu pr...   P_Neutral   P_Neutral
# 3   Hvala lepa. Gospod Černač v imenu predlagatelj...   P_Neutral   P_Neutral
# 4   Bom zelo kratek. Tam za mizo smo imeli vodje p...    Negative    Negative
# 5   Hvala lepa. Besedo ima gospa Alenka Jeraj, pri...   P_Neutral   P_Neutral
# 6                                 Minister, izvolite.   P_Neutral   P_Neutral
# 7   Hvala lepa. S tem zaključujem razpravo. Na pod...   P_Neutral   P_Neutral
# 8   Da, seveda, da ne bi izzvenelo, da so bile moj...    Negative    Negative
# 9          Hvala lepa. Besedo ima gospod Mirko Brulc.   P_Neutral   P_Neutral
# 10  Hvala za besedo. Že prejšnji amandma sem podpr...    Positive    Positive
# 11  Hvala lepa, gospod Grill. V imenu Poslanske sk...   P_Neutral   P_Neutral
# 12  Hvala lepa. Poslanska skupina Pozitivna Sloven...   P_Neutral   P_Neutral
# 13  Hvala lepa tudi vam. Gospod Franc Bogovič, izv...   P_Neutral   P_Neutral
# 14  Hvala. Sicer pa bomo o amandmajih v skladu s č...   P_Neutral   P_Neutral
# 15  Hvala lepa. Kot sem napovedal že v stališču po...    Negative    Negative
# 16  Hvala lepa, gospod predsednik, za besedo. Spoš...   N_Neutral    Negative
# 17         To je prvi del. Drugi del je pa to [[...]]   P_Neutral   P_Neutral
# 18  Povejte, prosim, kateri so zaslužni za to, da ...    Negative    Negative
# 19  Hvala, gospa predsedujoča. Kolegice in kolegi!...    Negative  M_Negative
# 20  Hvala tudi vam. Gospod Branko Ficko bo obrazlo...   P_Neutral   P_Neutral
# 21  Hvala. Mag. Marko Pogačnik bo predstavil stali...   P_Neutral   P_Neutral
# 22  Hvala lepa, gospa podpredsednica. Spoštovani g...   P_Neutral   P_Neutral
# 23  Hvala lepa. Prehajamo na glasovanje. Prekinjam...   P_Neutral   P_Neutral
# 24  Hvala lepa. Kot predlagatelj ste se javili, go...   P_Neutral   N_Neutral
# 25  Hvala lepa, gospod predsednik. Moj postopkovni...   N_Neutral    Negative
# 26           Hvala. Besedo ima gospod Jožef Jerovšek.   P_Neutral   P_Neutral
# 27  Hvala. Besedo ima gospod Matevž Frangež. Izvol...   P_Neutral   P_Neutral
# 28  Hvala. Amandma Slovenske demokratske stranke b...  M_Negative  M_Negative
# 29  Hvala lepa. Niti nisem želela odreagirati na t...    Negative    Negative
# 30  Res so bili koalicijski poslanci doslej bolj r...    Negative  M_Positive
# 31  Že prej sem vas prosil, predsedujoča, le da je...    Negative    Negative
# 32  Gospa podpredsednica, lepo vas prosim, da pozo...    Negative    Negative
# 33  Želi še kdo obrazložiti glas? Ugotavljam, da n...   P_Neutral   P_Neutral
# 34  Hvala. Besedo ima gospod Franc Pukšič v imenu ...   P_Neutral   P_Neutral
# 35  Hvala lepa. 45. člen zakona o izvrševanju pror...    Negative    Negative
# 36  Hvala lepa. To vsekakor zahteva nek odziv na t...    Negative    Negative
# 37  Še enkrat, amandma k prvi točki govori o tem, ...    Positive   P_Neutral
# 38  Hvala lepa. Besedo ima mag. Ivan Vogrin. Vidim...   P_Neutral   P_Neutral
# 39  Spoštovani gospod predsednik, hvala za besedo....    Positive    Positive
# 40  Najlepša hvala, gospa Novak, za to vprašanje. ...  M_Positive  M_Positive
# 41  Hvala lepa. To, kar je sedaj nazadnje rekel mi...    Positive    Negative
# 42  Hvala. V zvezi s problematiko ravnanja z odpad...   P_Neutral   P_Neutral
# 43         Hvala lepa. Dr. Anja Kopač Mrak, izvolite.   P_Neutral   P_Neutral
# 44  Spoštovana predsedujoča, predstavniki Vlade, k...  M_Positive  M_Positive
# 45  Hvala. Postopkovno zahtevo ima gospa Ljudmila ...   P_Neutral   P_Neutral
# 46                         Gospod minister, izvolite.   P_Neutral   P_Neutral
# 47  Najlepša hvala, gospod poslanec Breznik. Z vam...   P_Neutral  M_Positive
# 48  Hvala za dodatno vprašanje. Dejansko je res, g...   P_Neutral  M_Negative
# 49  Sledim gospa Potrata. Tri minute so ravnokar m...   N_Neutral   N_Neutral
#
#                                       comments_tamara
# 0            Purely ceremnial, opening of a session.   \
# 1                                Lots of facts, TLDR…
# 2                                          Procedural
# 3                                          Procedural
# 4   Could be N_Neutral also, but I thing this has ...
# 5                                          Procedural
# 6                                          Procedural
# 7                                          Procedural
# 8                       Negative, mocking sentiment.
# 9                                        Ceremonial.
# 10                            Support for something,
# 11                                         Procedural
# 12                                         Procedural
# 13                                         Procedural
# 14                   Procedural, the speakers words.
# 15  Although the speaker expresses a rather neutra...
# 16  States objective facts that shows some negativ...
# 17                                         Procedural
# 18             I also think this could be sarcastic.
# 19            Negative opinion and also ''očitajoče''
# 20                                         Procedural
# 21                                         Procedural
# 22  Although it expresses a support for the amendm...
# 23                                         Procedural
# 24                                         Procedural
# 25  Rather neutral,questions, but a bit of a negat...
# 26                                         Procedural
# 27                                         Procedural
# 28  First part support of, but second part express...
# 29               Clearly expressed negative opinion.
# 30  I think this is ''očitajoče'' towards the pres...
# 31                                Expressed opinion.
# 32                                 mocking, demanding
# 33                                         Procedural
# 34                                         Procedural
# 35  Although in the name of a group, it clearly ex...
# 36                  Expressive, negative words used.
# 37                        Support, nothing negative.
# 38                                       Procedural.
# 39                           Clear widespread support
# 40  Some positive - priority for the youth, but al...
# 41  Despite the negative word ''zlorabiti'' this i...
# 42                                        Just facts.
# 43                                       Procedural.
# 44  At first very negative topic and fact, but at ...
# 45                                         Procedural
# 46                                         Procedural
# 47  Although there is some agreement in the first ...
# 48  Pure facts, although if we look at it from the...
# 49              Ceremonialno, z negativnim prizvokom.
#
#                                        comments_katja flagged_tamara
# 0                            Procedural, no sentiment            NaN  \
# 1   Speaker talks about a very negative topic of c...              T
# 2                                                 NaN            NaN
# 3                                                 NaN            NaN
# 4                                                 NaN            NaN
# 5                                                 NaN            NaN
# 6                                                 NaN            NaN
# 7   Procedural, slight negative sentiment due to t...            NaN
# 8                                                 NaN            NaN
# 9                                                 NaN            NaN
# 10                                                NaN            NaN
# 11                                                NaN            NaN
# 12                                                NaN            NaN
# 13                                                NaN            NaN
# 14                                                NaN            NaN
# 15                                                NaN            NaN
# 16                                                NaN            NaN
# 17                                                NaN            NaN
# 18                                                NaN            NaN
# 19                                                NaN            NaN
# 20                                                NaN            NaN
# 21                                                NaN            NaN
# 22  Lots of factual statements, with regards to th...            NaN
# 23                                                NaN            NaN
# 24                                                NaN            NaN
# 25                                                NaN            NaN
# 26                                                NaN            NaN
# 27                                                NaN            NaN
# 28  First part positive ("I will support, because....            NaN
# 29                                                NaN            NaN
# 30  Very mixed, sentiment changes several times th...            NaN
# 31                                                NaN            NaN
# 32                                                NaN            NaN
# 33                                                NaN            NaN
# 34                                                NaN            NaN
# 35                                                NaN            NaN
# 36                                                NaN            NaN
# 37  Difficult to pinpoint sentiment, as it seems r...            NaN
# 38                                                NaN            NaN
# 39  Again, very neutral, or at least not with very...            NaN
# 40  First part very negative and dealing with accu...            NaN
# 41                                                NaN            NaN
# 42                                                NaN            NaN
# 43                                                NaN            NaN
# 44                                                NaN            NaN
# 45                                                NaN            NaN
# 46                                                NaN            NaN
# 47                                                NaN            NaN
# 48                                                NaN            NaN
# 49                                                NaN            NaN
#
#    flagged_katja chair  final_tag sent_tamara sent_katja
# 0            NaN  True        NaN     Neutral    Neutral
# 1            NaN   NaN        NaN     Neutral   Positive
# 2            NaN  True        NaN     Neutral    Neutral
# 3            NaN  True        NaN     Neutral    Neutral
# 4            NaN   NaN        NaN    Negative   Negative
# 5            NaN  True        NaN     Neutral    Neutral
# 6            NaN  True        NaN     Neutral    Neutral
# 7            NaN  True        NaN     Neutral    Neutral
# 8            NaN   NaN        NaN    Negative   Negative
# 9            NaN  True        NaN     Neutral    Neutral
# 10           NaN   NaN        NaN    Positive   Positive
# 11           NaN  True        NaN     Neutral    Neutral
# 12           NaN  True        NaN     Neutral    Neutral
# 13           NaN  True        NaN     Neutral    Neutral
# 14           NaN  True        NaN     Neutral    Neutral
# 15           NaN   NaN        NaN    Negative   Negative
# 16           NaN   NaN        NaN     Neutral   Negative
# 17           NaN   NaN        NaN     Neutral    Neutral
# 18           NaN   NaN        NaN    Negative   Negative
# 19          True   NaN        NaN    Negative   Negative
# 20           NaN  True        NaN     Neutral    Neutral
# 21           NaN  True        NaN     Neutral    Neutral
# 22           NaN   NaN        NaN     Neutral    Neutral
# 23           NaN  True        NaN     Neutral    Neutral
# 24           NaN  True        NaN     Neutral    Neutral
# 25           NaN   NaN        NaN     Neutral   Negative
# 26           NaN  True        NaN     Neutral    Neutral
# 27           NaN  True        NaN     Neutral    Neutral
# 28           NaN   NaN        NaN    Negative   Negative
# 29           NaN   NaN        NaN    Negative   Negative
# 30          True   NaN        NaN    Negative   Positive
# 31           NaN   NaN        NaN    Negative   Negative
# 32           NaN   NaN        NaN    Negative   Negative
# 33           NaN  True        NaN     Neutral    Neutral
# 34           NaN  True        NaN     Neutral    Neutral
# 35           NaN   NaN        NaN    Negative   Negative
# 36           NaN   NaN        NaN    Negative   Negative
# 37          True   NaN        NaN    Positive    Neutral
# 38           NaN  True        NaN     Neutral    Neutral
# 39          True   NaN        NaN    Positive   Positive
# 40          True   NaN        NaN    Positive   Positive
# 41           NaN   NaN        NaN    Positive   Negative
# 42           NaN   NaN        NaN     Neutral    Neutral
# 43           NaN  True        NaN     Neutral    Neutral
# 44           NaN   NaN        NaN    Positive   Positive
# 45           NaN  True        NaN     Neutral    Neutral
# 46           NaN  True        NaN     Neutral    Neutral
# 47          True   NaN        NaN     Neutral   Positive
# 48           NaN   NaN        NaN     Neutral   Negative
# 49           NaN  True        NaN     Neutral    Neutral

# %%
annotator1 = df['sent_tamara']
annotator2 = df['sent_katja']
cohen_kappa_score(annotator1, annotator2)
# Out:
# 0.7105643994211288

# %% [markdown]
# # Generating dataset for consolidation
#
# Adding new column for the final annotation, provided with consolidation
#
# Note: Comment out after consolidation dataset is created

# %%
#df['final_tag'] = df.apply(lambda row: row['tag_tamara'] if row['tag_tamara'] == row['tag_katja'] else None, axis=1)

# %%
#df.to_csv("Test2_consolidation.csv", encoding = 'utf-8')
