# %%
import csv
import pandas as pd

# %% [markdown]
# # Dataset merge and prep for analysis
#
# Checking and renaming the datasets to merge them into one combined dataset and get it ready for (IAA) analysis.
#
# Change folder (Test1, Test2, Main1, Main2...) to process other datasets as they come.

# %%
df1 = pd.read_csv("Test2/Test2_Tamara.csv", encoding='utf-8', delimiter=';')
df2 = pd.read_csv("Test2/Test2_Katja.csv", encoding='utf-8', delimiter=';')

# %%
df2
# Out:
#                                               ID
# 0     ParlaMint-SI_2013-06-21-SDZ6-Izredna-39.u1  \
# 1    ParlaMint-SI_2013-04-26-SDZ6-Izredna-33.u41
# 2      ParlaMint-SI_2013-11-20-SDZ6-Redna-19.u47
# 3     ParlaMint-SI_2013-11-20-SDZ6-Redna-19.u147
# 4     ParlaMint-SI_2013-11-20-SDZ6-Redna-19.u247
# 5      ParlaMint-SI_2013-01-31-SDZ6-Redna-10.u49
# 6     ParlaMint-SI_2013-01-31-SDZ6-Redna-10.u149
# 7     ParlaMint-SI_2013-01-31-SDZ6-Redna-10.u249
# 8      ParlaMint-SI_2013-07-10-SDZ6-Redna-16.u96
# 9      ParlaMint-SI_2013-03-05-SDZ6-Redna-11.u43
# 10    ParlaMint-SI_2013-03-05-SDZ6-Redna-11.u143
# 11     ParlaMint-SI_2013-11-27-SDZ6-Redna-19.u83
# 12    ParlaMint-SI_2013-11-27-SDZ6-Redna-19.u183
# 13    ParlaMint-SI_2013-11-27-SDZ6-Redna-19.u283
# 14     ParlaMint-SI_2013-06-18-SDZ6-Redna-15.u65
# 15    ParlaMint-SI_2013-06-18-SDZ6-Redna-15.u165
# 16   ParlaMint-SI_2013-11-29-SDZ6-Izredna-48.u34
# 17  ParlaMint-SI_2013-11-29-SDZ6-Izredna-48.u134
# 18     ParlaMint-SI_2013-06-20-SDZ6-Redna-15.u60
# 19    ParlaMint-SI_2013-06-20-SDZ6-Redna-15.u160
# 20    ParlaMint-SI_2013-06-20-SDZ6-Redna-15.u260
# 21     ParlaMint-SI_2013-04-24-SDZ6-Redna-13.u53
# 22    ParlaMint-SI_2013-04-24-SDZ6-Redna-13.u153
# 23    ParlaMint-SI_2013-04-24-SDZ6-Redna-13.u253
# 24   ParlaMint-SI_2013-12-12-SDZ6-Izredna-50.u47
# 25   ParlaMint-SI_2013-12-12-SDZ6-Izredna-51.u38
# 26   ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u95
# 27  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u195
# 28  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u295
# 29  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u395
# 30  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u495
# 31  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u595
# 32  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u695
# 33  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u795
# 34  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u895
# 35  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u995
# 36   ParlaMint-SI_2013-09-20-SDZ6-Izredna-43.u78
# 37  ParlaMint-SI_2013-09-20-SDZ6-Izredna-43.u178
# 38     ParlaMint-SI_2013-03-06-SDZ6-Redna-11.u57
# 39     ParlaMint-SI_2013-03-27-SDZ6-Redna-12.u72
# 40     ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u18
# 41    ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u118
# 42    ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u218
# 43    ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u318
# 44     ParlaMint-SI_2013-04-23-SDZ6-Redna-13.u86
# 45     ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u37
# 46    ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u137
# 47    ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u237
# 48    ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u337
# 49     ParlaMint-SI_2013-07-15-SDZ6-Redna-16.u97
#
#                                                  Text  Annotation
# 0   Spoštovani kolegice poslanke in kolegi poslanc...   P_Neutral  \
# 1   Hvala lepa, spoštovani gospod predsednik. Gosp...  M_Positive
# 2   Hvala lepa. Gospod Černač, izvolite v imenu pr...   P_Neutral
# 3   Hvala lepa. Gospod Černač v imenu predlagatelj...   P_Neutral
# 4   Bom zelo kratek. Tam za mizo smo imeli vodje p...    Negative
# 5   Hvala lepa. Besedo ima gospa Alenka Jeraj, pri...   P_Neutral
# 6                                 Minister, izvolite.   P_Neutral
# 7   Hvala lepa. S tem zaključujem razpravo. Na pod...   P_Neutral
# 8   Da, seveda, da ne bi izzvenelo, da so bile moj...    Negative
# 9          Hvala lepa. Besedo ima gospod Mirko Brulc.   P_Neutral
# 10  Hvala za besedo. Že prejšnji amandma sem podpr...    Positive
# 11  Hvala lepa, gospod Grill. V imenu Poslanske sk...   P_Neutral
# 12  Hvala lepa. Poslanska skupina Pozitivna Sloven...   P_Neutral
# 13  Hvala lepa tudi vam. Gospod Franc Bogovič, izv...   P_Neutral
# 14  Hvala. Sicer pa bomo o amandmajih v skladu s č...   P_Neutral
# 15  Hvala lepa. Kot sem napovedal že v stališču po...    Negative
# 16  Hvala lepa, gospod predsednik, za besedo. Spoš...    Negative
# 17         To je prvi del. Drugi del je pa to [[...]]   P_Neutral
# 18  Povejte, prosim, kateri so zaslužni za to, da ...    Negative
# 19  Hvala, gospa predsedujoča. Kolegice in kolegi!...  M_Negative
# 20  Hvala tudi vam. Gospod Branko Ficko bo obrazlo...   P_Neutral
# 21  Hvala. Mag. Marko Pogačnik bo predstavil stali...   P_Neutral
# 22  Hvala lepa, gospa podpredsednica. Spoštovani g...   P_Neutral
# 23  Hvala lepa. Prehajamo na glasovanje. Prekinjam...   P_Neutral
# 24  Hvala lepa. Kot predlagatelj ste se javili, go...   N_Neutral
# 25  Hvala lepa, gospod predsednik. Moj postopkovni...    Negative
# 26           Hvala. Besedo ima gospod Jožef Jerovšek.   P_Neutral
# 27  Hvala. Besedo ima gospod Matevž Frangež. Izvol...   P_Neutral
# 28  Hvala. Amandma Slovenske demokratske stranke b...  M_Negative
# 29  Hvala lepa. Niti nisem želela odreagirati na t...    Negative
# 30  Res so bili koalicijski poslanci doslej bolj r...  M_Positive
# 31  Že prej sem vas prosil, predsedujoča, le da je...    Negative
# 32  Gospa podpredsednica, lepo vas prosim, da pozo...    Negative
# 33  Želi še kdo obrazložiti glas? Ugotavljam, da n...   P_Neutral
# 34  Hvala. Besedo ima gospod Franc Pukšič v imenu ...   P_Neutral
# 35  Hvala lepa. 45. člen zakona o izvrševanju pror...    Negative
# 36  Hvala lepa. To vsekakor zahteva nek odziv na t...    Negative
# 37  Še enkrat, amandma k prvi točki govori o tem, ...   P_Neutral
# 38  Hvala lepa. Besedo ima mag. Ivan Vogrin. Vidim...   P_Neutral
# 39  Spoštovani gospod predsednik, hvala za besedo....    Positive
# 40  Najlepša hvala, gospa Novak, za to vprašanje. ...  M_Positive
# 41  Hvala lepa. To, kar je sedaj nazadnje rekel mi...    Negative
# 42  Hvala. V zvezi s problematiko ravnanja z odpad...   P_Neutral
# 43         Hvala lepa. Dr. Anja Kopač Mrak, izvolite.   P_Neutral
# 44  Spoštovana predsedujoča, predstavniki Vlade, k...  M_Positive
# 45  Hvala. Postopkovno zahtevo ima gospa Ljudmila ...   P_Neutral
# 46                         Gospod minister, izvolite.   P_Neutral
# 47  Najlepša hvala, gospod poslanec Breznik. Z vam...  M_Positive
# 48  Hvala za dodatno vprašanje. Dejansko je res, g...  M_Negative
# 49  Sledim gospa Potrata. Tri minute so ravnokar m...   N_Neutral
#
#                                              Comments  Flag Chair
# 0                            Procedural, no sentiment   NaN  True
# 1   Speaker talks about a very negative topic of c...   NaN   NaN
# 2                                                 NaN   NaN  True
# 3                                                 NaN   NaN  True
# 4                                                 NaN   NaN   NaN
# 5                                                 NaN   NaN  True
# 6                                                 NaN   NaN  True
# 7   Procedural, slight negative sentiment due to t...   NaN  True
# 8                                                 NaN   NaN   NaN
# 9                                                 NaN   NaN  True
# 10                                                NaN   NaN   NaN
# 11                                                NaN   NaN  True
# 12                                                NaN   NaN  True
# 13                                                NaN   NaN  True
# 14                                                NaN   NaN  True
# 15                                                NaN   NaN   NaN
# 16                                                NaN   NaN   NaN
# 17                                                NaN   NaN   NaN
# 18                                                NaN   NaN   NaN
# 19                                                NaN  True   NaN
# 20                                                NaN   NaN  True
# 21                                                NaN   NaN  True
# 22  Lots of factual statements, with regards to th...   NaN   NaN
# 23                                                NaN   NaN  True
# 24                                                NaN   NaN  True
# 25                                                NaN   NaN   NaN
# 26                                                NaN   NaN  True
# 27                                                NaN   NaN  True
# 28  First part positive ("I will support, because....   NaN   NaN
# 29                                                NaN   NaN   NaN
# 30  Very mixed, sentiment changes several times th...  True   NaN
# 31                                                NaN   NaN   NaN
# 32                                                NaN   NaN   NaN
# 33                                                NaN   NaN  True
# 34                                                NaN   NaN  True
# 35                                                NaN   NaN   NaN
# 36                                                NaN   NaN   NaN
# 37  Difficult to pinpoint sentiment, as it seems r...  True   NaN
# 38                                                NaN   NaN  True
# 39  Again, very neutral, or at least not with very...  True   NaN
# 40  First part very negative and dealing with accu...  True   NaN
# 41                                                NaN   NaN   NaN
# 42                                                NaN   NaN   NaN
# 43                                                NaN   NaN  True
# 44                                                NaN   NaN   NaN
# 45                                                NaN   NaN  True
# 46                                                NaN   NaN  True
# 47                                                NaN  True   NaN
# 48                                                NaN   NaN   NaN
# 49                                                NaN   NaN  True

# %%
df1.rename(columns={'Text':'text', 'Annotation': 'tag_tamara', 'Comments': 'comments_tamara','Flag':'flagged_tamara'}, inplace=True)

# %%
df2.rename(columns={'Text':'text', 'Annotation': 'tag_katja', 'Comments': 'comments_katja','Flag':'flagged_katja', 'Chair':'chair'}, inplace=True)

# %%
merged_df = pd.merge(df1, df2, on=['ID', 'text'])
merged_df
# Out:
#                                               ID
# 0     ParlaMint-SI_2013-06-21-SDZ6-Izredna-39.u1  \
# 1    ParlaMint-SI_2013-04-26-SDZ6-Izredna-33.u41
# 2      ParlaMint-SI_2013-11-20-SDZ6-Redna-19.u47
# 3     ParlaMint-SI_2013-11-20-SDZ6-Redna-19.u147
# 4     ParlaMint-SI_2013-11-20-SDZ6-Redna-19.u247
# 5      ParlaMint-SI_2013-01-31-SDZ6-Redna-10.u49
# 6     ParlaMint-SI_2013-01-31-SDZ6-Redna-10.u149
# 7     ParlaMint-SI_2013-01-31-SDZ6-Redna-10.u249
# 8      ParlaMint-SI_2013-07-10-SDZ6-Redna-16.u96
# 9      ParlaMint-SI_2013-03-05-SDZ6-Redna-11.u43
# 10    ParlaMint-SI_2013-03-05-SDZ6-Redna-11.u143
# 11     ParlaMint-SI_2013-11-27-SDZ6-Redna-19.u83
# 12    ParlaMint-SI_2013-11-27-SDZ6-Redna-19.u183
# 13    ParlaMint-SI_2013-11-27-SDZ6-Redna-19.u283
# 14     ParlaMint-SI_2013-06-18-SDZ6-Redna-15.u65
# 15    ParlaMint-SI_2013-06-18-SDZ6-Redna-15.u165
# 16   ParlaMint-SI_2013-11-29-SDZ6-Izredna-48.u34
# 17  ParlaMint-SI_2013-11-29-SDZ6-Izredna-48.u134
# 18     ParlaMint-SI_2013-06-20-SDZ6-Redna-15.u60
# 19    ParlaMint-SI_2013-06-20-SDZ6-Redna-15.u160
# 20    ParlaMint-SI_2013-06-20-SDZ6-Redna-15.u260
# 21     ParlaMint-SI_2013-04-24-SDZ6-Redna-13.u53
# 22    ParlaMint-SI_2013-04-24-SDZ6-Redna-13.u153
# 23    ParlaMint-SI_2013-04-24-SDZ6-Redna-13.u253
# 24   ParlaMint-SI_2013-12-12-SDZ6-Izredna-50.u47
# 25   ParlaMint-SI_2013-12-12-SDZ6-Izredna-51.u38
# 26   ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u95
# 27  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u195
# 28  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u295
# 29  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u395
# 30  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u495
# 31  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u595
# 32  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u695
# 33  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u795
# 34  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u895
# 35  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u995
# 36   ParlaMint-SI_2013-09-20-SDZ6-Izredna-43.u78
# 37  ParlaMint-SI_2013-09-20-SDZ6-Izredna-43.u178
# 38     ParlaMint-SI_2013-03-06-SDZ6-Redna-11.u57
# 39     ParlaMint-SI_2013-03-27-SDZ6-Redna-12.u72
# 40     ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u18
# 41    ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u118
# 42    ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u218
# 43    ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u318
# 44     ParlaMint-SI_2013-04-23-SDZ6-Redna-13.u86
# 45     ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u37
# 46    ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u137
# 47    ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u237
# 48    ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u337
# 49     ParlaMint-SI_2013-07-15-SDZ6-Redna-16.u97
#
#                                                  text  tag_tamara
# 0   Spoštovani kolegice poslanke in kolegi poslanc...   P_Neutral  \
# 1   Hvala lepa, spoštovani gospod predsednik. Gosp...   N_Neutral
# 2   Hvala lepa. Gospod Černač, izvolite v imenu pr...   P_Neutral
# 3   Hvala lepa. Gospod Černač v imenu predlagatelj...   P_Neutral
# 4   Bom zelo kratek. Tam za mizo smo imeli vodje p...    Negative
# 5   Hvala lepa. Besedo ima gospa Alenka Jeraj, pri...   P_Neutral
# 6                                 Minister, izvolite.   P_Neutral
# 7   Hvala lepa. S tem zaključujem razpravo. Na pod...   P_Neutral
# 8   Da, seveda, da ne bi izzvenelo, da so bile moj...    Negative
# 9          Hvala lepa. Besedo ima gospod Mirko Brulc.   P_Neutral
# 10  Hvala za besedo. Že prejšnji amandma sem podpr...    Positive
# 11  Hvala lepa, gospod Grill. V imenu Poslanske sk...   P_Neutral
# 12  Hvala lepa. Poslanska skupina Pozitivna Sloven...   P_Neutral
# 13  Hvala lepa tudi vam. Gospod Franc Bogovič, izv...   P_Neutral
# 14  Hvala. Sicer pa bomo o amandmajih v skladu s č...   P_Neutral
# 15  Hvala lepa. Kot sem napovedal že v stališču po...    Negative
# 16  Hvala lepa, gospod predsednik, za besedo. Spoš...  N_Neutral
# 17         To je prvi del. Drugi del je pa to [[...]]   P_Neutral
# 18  Povejte, prosim, kateri so zaslužni za to, da ...    Negative
# 19  Hvala, gospa predsedujoča. Kolegice in kolegi!...    Negative
# 20  Hvala tudi vam. Gospod Branko Ficko bo obrazlo...   P_Neutral
# 21  Hvala. Mag. Marko Pogačnik bo predstavil stali...   P_Neutral
# 22  Hvala lepa, gospa podpredsednica. Spoštovani g...   P_Neutral
# 23  Hvala lepa. Prehajamo na glasovanje. Prekinjam...   P_Neutral
# 24  Hvala lepa. Kot predlagatelj ste se javili, go...   P_Neutral
# 25  Hvala lepa, gospod predsednik. Moj postopkovni...   N_Neutral
# 26           Hvala. Besedo ima gospod Jožef Jerovšek.   P_Neutral
# 27  Hvala. Besedo ima gospod Matevž Frangež. Izvol...   P_Neutral
# 28  Hvala. Amandma Slovenske demokratske stranke b...  M_Negative
# 29  Hvala lepa. Niti nisem želela odreagirati na t...    Negative
# 30  Res so bili koalicijski poslanci doslej bolj r...    Negative
# 31  Že prej sem vas prosil, predsedujoča, le da je...    Negative
# 32  Gospa podpredsednica, lepo vas prosim, da pozo...    Negative
# 33  Želi še kdo obrazložiti glas? Ugotavljam, da n...   P_Neutral
# 34  Hvala. Besedo ima gospod Franc Pukšič v imenu ...   P_Neutral
# 35  Hvala lepa. 45. člen zakona o izvrševanju pror...    Negative
# 36  Hvala lepa. To vsekakor zahteva nek odziv na t...    Negative
# 37  Še enkrat, amandma k prvi točki govori o tem, ...    Positive
# 38  Hvala lepa. Besedo ima mag. Ivan Vogrin. Vidim...   P_Neutral
# 39  Spoštovani gospod predsednik, hvala za besedo....    Positive
# 40  Najlepša hvala, gospa Novak, za to vprašanje. ...  M_Positive
# 41  Hvala lepa. To, kar je sedaj nazadnje rekel mi...    Positive
# 42  Hvala. V zvezi s problematiko ravnanja z odpad...   P_Neutral
# 43         Hvala lepa. Dr. Anja Kopač Mrak, izvolite.   P_Neutral
# 44  Spoštovana predsedujoča, predstavniki Vlade, k...  M_Positive
# 45  Hvala. Postopkovno zahtevo ima gospa Ljudmila ...   P_Neutral
# 46                         Gospod minister, izvolite.   P_Neutral
# 47  Najlepša hvala, gospod poslanec Breznik. Z vam...   P_Neutral
# 48  Hvala za dodatno vprašanje. Dejansko je res, g...   P_Neutral
# 49  Sledim gospa Potrata. Tri minute so ravnokar m...  N_Neutral
#
#                                       comments_tamara flagged_tamara
# 0            Purely ceremnial, opening of a session.             NaN  \
# 1                                Lots of facts, TLDR…              T
# 2                                          Procedural            NaN
# 3                                          Procedural            NaN
# 4   Could be N_Neutral also, but I thing this has ...            NaN
# 5                                          Procedural            NaN
# 6                                          Procedural            NaN
# 7                                          Procedural            NaN
# 8                       Negative, mocking sentiment.             NaN
# 9                                        Ceremonial.             NaN
# 10                            Support for something,             NaN
# 11                                         Procedural            NaN
# 12                                         Procedural            NaN
# 13                                         Procedural            NaN
# 14                   Procedural, the speakers words.             NaN
# 15  Although the speaker expresses a rather neutra...            NaN
# 16  States objective facts that shows some negativ...            NaN
# 17                                         Procedural            NaN
# 18             I also think this could be sarcastic.             NaN
# 19            Negative opinion and also ''očitajoče''            NaN
# 20                                         Procedural            NaN
# 21                                         Procedural            NaN
# 22  Although it expresses a support for the amendm...            NaN
# 23                                         Procedural            NaN
# 24                                         Procedural            NaN
# 25  Rather neutral,questions, but a bit of a negat...            NaN
# 26                                         Procedural            NaN
# 27                                         Procedural            NaN
# 28  First part support of, but second part express...            NaN
# 29               Clearly expressed negative opinion.             NaN
# 30  I think this is ''očitajoče'' towards the pres...            NaN
# 31                                Expressed opinion.             NaN
# 32                                 mocking, demanding            NaN
# 33                                         Procedural            NaN
# 34                                         Procedural            NaN
# 35  Although in the name of a group, it clearly ex...            NaN
# 36                  Expressive, negative words used.             NaN
# 37                        Support, nothing negative.             NaN
# 38                                       Procedural.             NaN
# 39                           Clear widespread support            NaN
# 40  Some positive - priority for the youth, but al...            NaN
# 41  Despite the negative word ''zlorabiti'' this i...            NaN
# 42                                        Just facts.            NaN
# 43                                       Procedural.             NaN
# 44  At first very negative topic and fact, but at ...            NaN
# 45                                         Procedural            NaN
# 46                                         Procedural            NaN
# 47  Although there is some agreement in the first ...            NaN
# 48  Pure facts, although if we look at it from the...            NaN
# 49              Ceremonialno, z negativnim prizvokom.            NaN
#
#      tag_katja                                     comments_katja
# 0    P_Neutral                           Procedural, no sentiment  \
# 1   M_Positive  Speaker talks about a very negative topic of c...
# 2    P_Neutral                                                NaN
# 3    P_Neutral                                                NaN
# 4     Negative                                                NaN
# 5    P_Neutral                                                NaN
# 6    P_Neutral                                                NaN
# 7    P_Neutral  Procedural, slight negative sentiment due to t...
# 8     Negative                                                NaN
# 9    P_Neutral                                                NaN
# 10    Positive                                                NaN
# 11   P_Neutral                                                NaN
# 12   P_Neutral                                                NaN
# 13   P_Neutral                                                NaN
# 14   P_Neutral                                                NaN
# 15    Negative                                                NaN
# 16    Negative                                                NaN
# 17   P_Neutral                                                NaN
# 18    Negative                                                NaN
# 19  M_Negative                                                NaN
# 20   P_Neutral                                                NaN
# 21   P_Neutral                                                NaN
# 22   P_Neutral  Lots of factual statements, with regards to th...
# 23   P_Neutral                                                NaN
# 24   N_Neutral                                                NaN
# 25    Negative                                                NaN
# 26   P_Neutral                                                NaN
# 27   P_Neutral                                                NaN
# 28  M_Negative  First part positive ("I will support, because....
# 29    Negative                                                NaN
# 30  M_Positive  Very mixed, sentiment changes several times th...
# 31    Negative                                                NaN
# 32    Negative                                                NaN
# 33   P_Neutral                                                NaN
# 34   P_Neutral                                                NaN
# 35    Negative                                                NaN
# 36    Negative                                                NaN
# 37   P_Neutral  Difficult to pinpoint sentiment, as it seems r...
# 38   P_Neutral                                                NaN
# 39    Positive  Again, very neutral, or at least not with very...
# 40  M_Positive  First part very negative and dealing with accu...
# 41    Negative                                                NaN
# 42   P_Neutral                                                NaN
# 43   P_Neutral                                                NaN
# 44  M_Positive                                                NaN
# 45   P_Neutral                                                NaN
# 46   P_Neutral                                                NaN
# 47  M_Positive                                                NaN
# 48  M_Negative                                                NaN
# 49   N_Neutral                                                NaN
#
#    flagged_katja chair
# 0            NaN  True
# 1            NaN   NaN
# 2            NaN  True
# 3            NaN  True
# 4            NaN   NaN
# 5            NaN  True
# 6            NaN  True
# 7            NaN  True
# 8            NaN   NaN
# 9            NaN  True
# 10           NaN   NaN
# 11           NaN  True
# 12           NaN  True
# 13           NaN  True
# 14           NaN  True
# 15           NaN   NaN
# 16           NaN   NaN
# 17           NaN   NaN
# 18           NaN   NaN
# 19          True   NaN
# 20           NaN  True
# 21           NaN  True
# 22           NaN   NaN
# 23           NaN  True
# 24           NaN  True
# 25           NaN   NaN
# 26           NaN  True
# 27           NaN  True
# 28           NaN   NaN
# 29           NaN   NaN
# 30          True   NaN
# 31           NaN   NaN
# 32           NaN   NaN
# 33           NaN  True
# 34           NaN  True
# 35           NaN   NaN
# 36           NaN   NaN
# 37          True   NaN
# 38           NaN  True
# 39          True   NaN
# 40          True   NaN
# 41           NaN   NaN
# 42           NaN   NaN
# 43           NaN  True
# 44           NaN   NaN
# 45           NaN  True
# 46           NaN  True
# 47          True   NaN
# 48           NaN   NaN
# 49           NaN  True

# %%
order = ['ID', 'text', 'tag_tamara', 'tag_katja', 'comments_tamara', 'comments_katja', 'flagged_tamara', 'flagged_katja', 'chair']

# %%
merged_df = merged_df[order]
merged_df['final_tag'] = ''
merged_df
# Out:
# /var/folders/ng/b52w03cd2d31sdjpmc5kyqlh0000gr/T/ipykernel_4642/111168188.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df['final_tag'] = ''
#                                               ID
# 0     ParlaMint-SI_2013-06-21-SDZ6-Izredna-39.u1  \
# 1    ParlaMint-SI_2013-04-26-SDZ6-Izredna-33.u41
# 2      ParlaMint-SI_2013-11-20-SDZ6-Redna-19.u47
# 3     ParlaMint-SI_2013-11-20-SDZ6-Redna-19.u147
# 4     ParlaMint-SI_2013-11-20-SDZ6-Redna-19.u247
# 5      ParlaMint-SI_2013-01-31-SDZ6-Redna-10.u49
# 6     ParlaMint-SI_2013-01-31-SDZ6-Redna-10.u149
# 7     ParlaMint-SI_2013-01-31-SDZ6-Redna-10.u249
# 8      ParlaMint-SI_2013-07-10-SDZ6-Redna-16.u96
# 9      ParlaMint-SI_2013-03-05-SDZ6-Redna-11.u43
# 10    ParlaMint-SI_2013-03-05-SDZ6-Redna-11.u143
# 11     ParlaMint-SI_2013-11-27-SDZ6-Redna-19.u83
# 12    ParlaMint-SI_2013-11-27-SDZ6-Redna-19.u183
# 13    ParlaMint-SI_2013-11-27-SDZ6-Redna-19.u283
# 14     ParlaMint-SI_2013-06-18-SDZ6-Redna-15.u65
# 15    ParlaMint-SI_2013-06-18-SDZ6-Redna-15.u165
# 16   ParlaMint-SI_2013-11-29-SDZ6-Izredna-48.u34
# 17  ParlaMint-SI_2013-11-29-SDZ6-Izredna-48.u134
# 18     ParlaMint-SI_2013-06-20-SDZ6-Redna-15.u60
# 19    ParlaMint-SI_2013-06-20-SDZ6-Redna-15.u160
# 20    ParlaMint-SI_2013-06-20-SDZ6-Redna-15.u260
# 21     ParlaMint-SI_2013-04-24-SDZ6-Redna-13.u53
# 22    ParlaMint-SI_2013-04-24-SDZ6-Redna-13.u153
# 23    ParlaMint-SI_2013-04-24-SDZ6-Redna-13.u253
# 24   ParlaMint-SI_2013-12-12-SDZ6-Izredna-50.u47
# 25   ParlaMint-SI_2013-12-12-SDZ6-Izredna-51.u38
# 26   ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u95
# 27  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u195
# 28  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u295
# 29  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u395
# 30  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u495
# 31  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u595
# 32  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u695
# 33  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u795
# 34  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u895
# 35  ParlaMint-SI_2013-11-14-SDZ6-Izredna-47.u995
# 36   ParlaMint-SI_2013-09-20-SDZ6-Izredna-43.u78
# 37  ParlaMint-SI_2013-09-20-SDZ6-Izredna-43.u178
# 38     ParlaMint-SI_2013-03-06-SDZ6-Redna-11.u57
# 39     ParlaMint-SI_2013-03-27-SDZ6-Redna-12.u72
# 40     ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u18
# 41    ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u118
# 42    ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u218
# 43    ParlaMint-SI_2013-11-18-SDZ6-Redna-19.u318
# 44     ParlaMint-SI_2013-04-23-SDZ6-Redna-13.u86
# 45     ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u37
# 46    ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u137
# 47    ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u237
# 48    ParlaMint-SI_2013-06-17-SDZ6-Redna-15.u337
# 49     ParlaMint-SI_2013-07-15-SDZ6-Redna-16.u97
#
#                                                  text  tag_tamara   tag_katja
# 0   Spoštovani kolegice poslanke in kolegi poslanc...   P_Neutral   P_Neutral  \
# 1   Hvala lepa, spoštovani gospod predsednik. Gosp...   N_Neutral  M_Positive
# 2   Hvala lepa. Gospod Černač, izvolite v imenu pr...   P_Neutral   P_Neutral
# 3   Hvala lepa. Gospod Černač v imenu predlagatelj...   P_Neutral   P_Neutral
# 4   Bom zelo kratek. Tam za mizo smo imeli vodje p...    Negative    Negative
# 5   Hvala lepa. Besedo ima gospa Alenka Jeraj, pri...   P_Neutral   P_Neutral
# 6                                 Minister, izvolite.   P_Neutral   P_Neutral
# 7   Hvala lepa. S tem zaključujem razpravo. Na pod...   P_Neutral   P_Neutral
# 8   Da, seveda, da ne bi izzvenelo, da so bile moj...    Negative    Negative
# 9          Hvala lepa. Besedo ima gospod Mirko Brulc.   P_Neutral   P_Neutral
# 10  Hvala za besedo. Že prejšnji amandma sem podpr...    Positive    Positive
# 11  Hvala lepa, gospod Grill. V imenu Poslanske sk...   P_Neutral   P_Neutral
# 12  Hvala lepa. Poslanska skupina Pozitivna Sloven...   P_Neutral   P_Neutral
# 13  Hvala lepa tudi vam. Gospod Franc Bogovič, izv...   P_Neutral   P_Neutral
# 14  Hvala. Sicer pa bomo o amandmajih v skladu s č...   P_Neutral   P_Neutral
# 15  Hvala lepa. Kot sem napovedal že v stališču po...    Negative    Negative
# 16  Hvala lepa, gospod predsednik, za besedo. Spoš...  N_Neutral     Negative
# 17         To je prvi del. Drugi del je pa to [[...]]   P_Neutral   P_Neutral
# 18  Povejte, prosim, kateri so zaslužni za to, da ...    Negative    Negative
# 19  Hvala, gospa predsedujoča. Kolegice in kolegi!...    Negative  M_Negative
# 20  Hvala tudi vam. Gospod Branko Ficko bo obrazlo...   P_Neutral   P_Neutral
# 21  Hvala. Mag. Marko Pogačnik bo predstavil stali...   P_Neutral   P_Neutral
# 22  Hvala lepa, gospa podpredsednica. Spoštovani g...   P_Neutral   P_Neutral
# 23  Hvala lepa. Prehajamo na glasovanje. Prekinjam...   P_Neutral   P_Neutral
# 24  Hvala lepa. Kot predlagatelj ste se javili, go...   P_Neutral   N_Neutral
# 25  Hvala lepa, gospod predsednik. Moj postopkovni...   N_Neutral    Negative
# 26           Hvala. Besedo ima gospod Jožef Jerovšek.   P_Neutral   P_Neutral
# 27  Hvala. Besedo ima gospod Matevž Frangež. Izvol...   P_Neutral   P_Neutral
# 28  Hvala. Amandma Slovenske demokratske stranke b...  M_Negative  M_Negative
# 29  Hvala lepa. Niti nisem želela odreagirati na t...    Negative    Negative
# 30  Res so bili koalicijski poslanci doslej bolj r...    Negative  M_Positive
# 31  Že prej sem vas prosil, predsedujoča, le da je...    Negative    Negative
# 32  Gospa podpredsednica, lepo vas prosim, da pozo...    Negative    Negative
# 33  Želi še kdo obrazložiti glas? Ugotavljam, da n...   P_Neutral   P_Neutral
# 34  Hvala. Besedo ima gospod Franc Pukšič v imenu ...   P_Neutral   P_Neutral
# 35  Hvala lepa. 45. člen zakona o izvrševanju pror...    Negative    Negative
# 36  Hvala lepa. To vsekakor zahteva nek odziv na t...    Negative    Negative
# 37  Še enkrat, amandma k prvi točki govori o tem, ...    Positive   P_Neutral
# 38  Hvala lepa. Besedo ima mag. Ivan Vogrin. Vidim...   P_Neutral   P_Neutral
# 39  Spoštovani gospod predsednik, hvala za besedo....    Positive    Positive
# 40  Najlepša hvala, gospa Novak, za to vprašanje. ...  M_Positive  M_Positive
# 41  Hvala lepa. To, kar je sedaj nazadnje rekel mi...    Positive    Negative
# 42  Hvala. V zvezi s problematiko ravnanja z odpad...   P_Neutral   P_Neutral
# 43         Hvala lepa. Dr. Anja Kopač Mrak, izvolite.   P_Neutral   P_Neutral
# 44  Spoštovana predsedujoča, predstavniki Vlade, k...  M_Positive  M_Positive
# 45  Hvala. Postopkovno zahtevo ima gospa Ljudmila ...   P_Neutral   P_Neutral
# 46                         Gospod minister, izvolite.   P_Neutral   P_Neutral
# 47  Najlepša hvala, gospod poslanec Breznik. Z vam...   P_Neutral  M_Positive
# 48  Hvala za dodatno vprašanje. Dejansko je res, g...   P_Neutral  M_Negative
# 49  Sledim gospa Potrata. Tri minute so ravnokar m...  N_Neutral    N_Neutral
#
#                                       comments_tamara
# 0            Purely ceremnial, opening of a session.   \
# 1                                Lots of facts, TLDR…
# 2                                          Procedural
# 3                                          Procedural
# 4   Could be N_Neutral also, but I thing this has ...
# 5                                          Procedural
# 6                                          Procedural
# 7                                          Procedural
# 8                       Negative, mocking sentiment.
# 9                                        Ceremonial.
# 10                            Support for something,
# 11                                         Procedural
# 12                                         Procedural
# 13                                         Procedural
# 14                   Procedural, the speakers words.
# 15  Although the speaker expresses a rather neutra...
# 16  States objective facts that shows some negativ...
# 17                                         Procedural
# 18             I also think this could be sarcastic.
# 19            Negative opinion and also ''očitajoče''
# 20                                         Procedural
# 21                                         Procedural
# 22  Although it expresses a support for the amendm...
# 23                                         Procedural
# 24                                         Procedural
# 25  Rather neutral,questions, but a bit of a negat...
# 26                                         Procedural
# 27                                         Procedural
# 28  First part support of, but second part express...
# 29               Clearly expressed negative opinion.
# 30  I think this is ''očitajoče'' towards the pres...
# 31                                Expressed opinion.
# 32                                 mocking, demanding
# 33                                         Procedural
# 34                                         Procedural
# 35  Although in the name of a group, it clearly ex...
# 36                  Expressive, negative words used.
# 37                        Support, nothing negative.
# 38                                       Procedural.
# 39                           Clear widespread support
# 40  Some positive - priority for the youth, but al...
# 41  Despite the negative word ''zlorabiti'' this i...
# 42                                        Just facts.
# 43                                       Procedural.
# 44  At first very negative topic and fact, but at ...
# 45                                         Procedural
# 46                                         Procedural
# 47  Although there is some agreement in the first ...
# 48  Pure facts, although if we look at it from the...
# 49              Ceremonialno, z negativnim prizvokom.
#
#                                        comments_katja flagged_tamara
# 0                            Procedural, no sentiment            NaN  \
# 1   Speaker talks about a very negative topic of c...              T
# 2                                                 NaN            NaN
# 3                                                 NaN            NaN
# 4                                                 NaN            NaN
# 5                                                 NaN            NaN
# 6                                                 NaN            NaN
# 7   Procedural, slight negative sentiment due to t...            NaN
# 8                                                 NaN            NaN
# 9                                                 NaN            NaN
# 10                                                NaN            NaN
# 11                                                NaN            NaN
# 12                                                NaN            NaN
# 13                                                NaN            NaN
# 14                                                NaN            NaN
# 15                                                NaN            NaN
# 16                                                NaN            NaN
# 17                                                NaN            NaN
# 18                                                NaN            NaN
# 19                                                NaN            NaN
# 20                                                NaN            NaN
# 21                                                NaN            NaN
# 22  Lots of factual statements, with regards to th...            NaN
# 23                                                NaN            NaN
# 24                                                NaN            NaN
# 25                                                NaN            NaN
# 26                                                NaN            NaN
# 27                                                NaN            NaN
# 28  First part positive ("I will support, because....            NaN
# 29                                                NaN            NaN
# 30  Very mixed, sentiment changes several times th...            NaN
# 31                                                NaN            NaN
# 32                                                NaN            NaN
# 33                                                NaN            NaN
# 34                                                NaN            NaN
# 35                                                NaN            NaN
# 36                                                NaN            NaN
# 37  Difficult to pinpoint sentiment, as it seems r...            NaN
# 38                                                NaN            NaN
# 39  Again, very neutral, or at least not with very...            NaN
# 40  First part very negative and dealing with accu...            NaN
# 41                                                NaN            NaN
# 42                                                NaN            NaN
# 43                                                NaN            NaN
# 44                                                NaN            NaN
# 45                                                NaN            NaN
# 46                                                NaN            NaN
# 47                                                NaN            NaN
# 48                                                NaN            NaN
# 49                                                NaN            NaN
#
#    flagged_katja chair final_tag
# 0            NaN  True
# 1            NaN   NaN
# 2            NaN  True
# 3            NaN  True
# 4            NaN   NaN
# 5            NaN  True
# 6            NaN  True
# 7            NaN  True
# 8            NaN   NaN
# 9            NaN  True
# 10           NaN   NaN
# 11           NaN  True
# 12           NaN  True
# 13           NaN  True
# 14           NaN  True
# 15           NaN   NaN
# 16           NaN   NaN
# 17           NaN   NaN
# 18           NaN   NaN
# 19          True   NaN
# 20           NaN  True
# 21           NaN  True
# 22           NaN   NaN
# 23           NaN  True
# 24           NaN  True
# 25           NaN   NaN
# 26           NaN  True
# 27           NaN  True
# 28           NaN   NaN
# 29           NaN   NaN
# 30          True   NaN
# 31           NaN   NaN
# 32           NaN   NaN
# 33           NaN  True
# 34           NaN  True
# 35           NaN   NaN
# 36           NaN   NaN
# 37          True   NaN
# 38           NaN  True
# 39          True   NaN
# 40          True   NaN
# 41           NaN   NaN
# 42           NaN   NaN
# 43           NaN  True
# 44           NaN   NaN
# 45           NaN  True
# 46           NaN  True
# 47          True   NaN
# 48           NaN   NaN
# 49           NaN  True

# %%
merged_df.to_csv("Test2/Test2_combined.csv", encoding ='utf-8', index=False)
